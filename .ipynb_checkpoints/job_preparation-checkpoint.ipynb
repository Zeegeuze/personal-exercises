# %% [markdown]
# # Preparation for future job hunt
#
# I want to use this notebook as a playground, but also as an overview for where to look for jobs.
#
# For this I want to use several criteria:
# * What countries am I interested in to move to
# * What countries is my wife interested in to move to
# * What are the regulations to start working in those countries
# * How popular is data science there (data scientists per capita / in total)
# * How many jobs are there for data scientists
# * How many jobs are there for deep learning / machine learning
# * How many professionals are there per job offer
# * What is the average wage in that place
#
# Some of my data will come from this source with data from 2020: [Towards data science](https://towardsdatascience.com/where-it-is-the-easiest-to-get-data-science-job-not-where-you-may-think-28e33ec652b3), recent data from [365 Data Science](https://365datascience.com/career-advice/data-science-salaries-around-the-world/) updated with own data.

# %%
# importing important stuff
# !pip install geopandas
# !pip install folium mapclassify
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
# Out:
# Requirement already satisfied: geopandas in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (0.14.3)
# Requirement already satisfied: fiona>=1.8.21 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from geopandas) (21.3)
# Requirement already satisfied: pandas>=1.4.0 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from geopandas) (1.4.4)
# Requirement already satisfied: pyproj>=3.3.0 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: attrs>=19.2.0 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (22.1.0)
# Requirement already satisfied: certifi in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (2022.9.24)
# Requirement already satisfied: click~=8.0 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (63.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2022.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (1.23.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from packaging->geopandas) (3.0.9)
# Requirement already satisfied: folium in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (0.12.1.post1)
# Requirement already satisfied: mapclassify in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (2.6.1)
# Requirement already satisfied: branca>=0.3.0 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from folium) (0.5.0)
# Requirement already satisfied: jinja2>=2.9 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from folium) (1.23.4)
# Requirement already satisfied: requests in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from folium) (2.28.1)
# Requirement already satisfied: networkx>=2.7 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from mapclassify) (2.8.7)
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from mapclassify) (1.4.4)
# Requirement already satisfied: scikit-learn>=1.0 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from mapclassify) (1.3.1)
# Requirement already satisfied: scipy>=1.8 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from mapclassify) (1.8.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas!=1.5.0,>=1.4->mapclassify) (2022.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from scikit-learn>=1.0->mapclassify) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from scikit-learn>=1.0->mapclassify) (3.1.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests->folium) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests->folium) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests->folium) (2022.9.24)
# Requirement already satisfied: six>=1.5 in /home/wouter/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas!=1.5.0,>=1.4->mapclassify) (1.16.0)

# %% [markdown]
# ## Download and show world map

# %%
# Load the datasets
detail_df = gpd.read_file('ne_110m_admin_0_scale_rank.zip')
c_v = gpd.read_file('https://osmtoday.com/africa/cape_verde.geojson')
romania = gpd.read_file('romania-with-regions_.geojson')
flanders = gpd.read_file('https://osmtoday.com/europe/belgium/flanders.geojson')

# %%
cluj = romania.loc[romania['name'].str.contains('cluj', case=False)]['geometry'].values[0]
timi = romania.loc[romania['name'].str.contains('timi', case=False)]['geometry'].values[0]

# %%
# Adding Cape Verde, Flanders and Transylvania to the df
detail_df.loc[len(detail_df.index)] = [1, 'Adm-0 scale ranks', 1, 'CPV', 'CPV', 'CVP', 'Cape Verde', c_v['geometry'].values[0]]
detail_df.loc[len(detail_df.index)] = [1, 'Adm-0 scale ranks', 1, 'TIMI', 'TIMI', 'TIMI', 'Timisoara', timi]
detail_df.loc[len(detail_df.index)] = [1, 'Adm-0 scale ranks', 1, 'CLUJ', 'CLUJ', 'CLUJ', 'Cluj', cluj]
detail_df.loc[len(detail_df.index)] = [1, 'Adm-0 scale ranks', 1, 'FLA', 'FLA', 'FLA', 'Flanders', flanders['geometry'].values[0]]

# %%
detail_df.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5dfcd20f0cf9cb40a93fb970ddbc2471 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5dfcd20f0cf9cb40a93fb970ddbc2471&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5dfcd20f0cf9cb40a93fb970ddbc2471 = L.map(
#                 &quot;map_5dfcd20f0cf9cb40a93fb970ddbc2471&quot;,
#                 {
#                     center: [-3.1774349999999956, 2.842170943040401e-14],
#                     crs: L.CRS.Simple,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5dfcd20f0cf9cb40a93fb970ddbc2471);
#
#
#
#
#
#             map_5dfcd20f0cf9cb40a93fb970ddbc2471.fitBounds(
#                 [[-90.0, -180.0], [83.64513000000001, 180.00000000000006]],
#                 {}
#             );
#
#
#         function geo_json_5385ddda897f1151b982fc97137c7c1c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5385ddda897f1151b982fc97137c7c1c_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5385ddda897f1151b982fc97137c7c1c_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_5385ddda897f1151b982fc97137c7c1c_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5385ddda897f1151b982fc97137c7c1c_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_5385ddda897f1151b982fc97137c7c1c.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5385ddda897f1151b982fc97137c7c1c_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5385ddda897f1151b982fc97137c7c1c = L.geoJson(null, {
#                 onEachFeature: geo_json_5385ddda897f1151b982fc97137c7c1c_onEachFeature,
#
#                 style: geo_json_5385ddda897f1151b982fc97137c7c1c_styler,
#                 pointToLayer: geo_json_5385ddda897f1151b982fc97137c7c1c_pointToLayer
#         });
#
#         function geo_json_5385ddda897f1151b982fc97137c7c1c_add (data) {
#             geo_json_5385ddda897f1151b982fc97137c7c1c
#                 .addData(data)
#                 .addTo(map_5dfcd20f0cf9cb40a93fb970ddbc2471);
#         }
#             geo_json_5385ddda897f1151b982fc97137c7c1c_add({&quot;bbox&quot;: [-180.0, -90.0, 180.00000000000006, 83.64513000000001], &quot;features&quot;: [{&quot;bbox&quot;: [178.59683859511713, -17.01204167436804, 180.0, -16.067132663642447], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[180.0, -16.067132663642447], [180.0, -16.555216566639196], [179.36414266196414, -16.801354076946883], [178.72505936299711, -17.01204167436804], [178.59683859511713, -16.639150000000004], [179.0966093629971, -16.433984277547403], [179.4135093629971, -16.379054277547404], [180.0, -16.067132663642447]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;featurecla&quot;: &quot;Adm-0 scale ranks&quot;, &quot;labelrank&quot;: 1, &quot;scalerank&quot;: 1, &quot;sr_adm0_a3&quot;: &quot;FJI&quot;, &quot;sr_geounit&quot;: &quot;Fiji&quot;, &quot;sr_gu_a3&quot;: &quot;FJI&quot;, &quot;sr_sov_a3&quot;: &quot;FJI&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [29.339997592900346, -11.720938002166735, 40.31659000000002, -0.9500000000000001], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[33.90371119710453, -0.9500000000000001], [34.07261999999997, -1.0598199999999451], [37.69868999999994, -3.0969899999999484], [37.7669, -3.6771200000000004], [39.20222, -4.67677], [38.74053999999995, -5.9089499999999475], [38.79977000000008, -6.475660000000005], [39.44, -6.839999999999861], [39.47000000000014, -7.099999999999966], [39.19468999999998, -7.703899999999976], [39.25203000000005, -8.00780999999995], [

# %% [markdown]
# ## Where I want to live

# %% [markdown]
# ### Code and charts

# %%
# Some countries I want to work in:
my_countries = ["Cape Verde", "Montenegro", "Cluj", "Flanders", "Netherlands", "El Salvador", "Belize", "Argentina", "Portugal", "Scotland", "Luxemburg", "Austria", "Switserland", "Slovakia", "Hungary", "Serbia", "Greece", "Belarus", "Finland", "Russia", "Cyprus", "Timisoara"]
work_me_df = pd.DataFrame({'countries': my_countries, 'his_rank': [1, 1, 1, 0.5, 0.1, 0.7, 0.6, 0.6, 0.7, 0.4, 1.0, 0.7, 0.65, 0.9, 0.8, 0.9, 0.7, 1.0, 0.75, 1.0, 0.7, 0.6]})
work_me_df
# Out:
#       countries  his_rank
# 0    Cape Verde      1.00
# 1    Montenegro      1.00
# 2          Cluj      1.00
# 3      Flanders      0.50
# 4   Netherlands      0.10
# 5   El Salvador      0.70
# 6        Belize      0.60
# 7     Argentina      0.60
# 8      Portugal      0.70
# 9      Scotland      0.40
# 10    Luxemburg      1.00
# 11      Austria      0.70
# 12  Switserland      0.65
# 13     Slovakia      0.90
# 14      Hungary      0.80
# 15       Serbia      0.90
# 16       Greece      0.70
# 17      Belarus      1.00
# 18      Finland      0.75
# 19       Russia      1.00
# 20       Cyprus      0.70
# 21    Timisoara      0.60

# %%
extended_df = detail_df.copy()
extended_df = pd.merge(detail_df, work_me_df, left_on=["sr_geounit"], right_on=["countries"], how="left")
extended_df = extended_df.drop(['countries'], axis=1)
extended_df['his_rank'] = extended_df['his_rank'].fillna(0)
extended_df = extended_df.set_crs(4326, allow_override=True)
extended_df
# Out:
#      scalerank         featurecla  labelrank sr_sov_a3 sr_adm0_a3 sr_gu_a3  \
# 0            1  Adm-0 scale ranks          1       FJI        FJI      FJI
# 1            1  Adm-0 scale ranks          1       TZA        TZA      TZA
# 2            1  Adm-0 scale ranks          1       SAH        SAH      SAH
# 3            1  Adm-0 scale ranks          1       CAN        CAN      CAN
# 4            1  Adm-0 scale ranks          1       US1        USA      USA
# ..         ...                ...        ...       ...        ...      ...
# 289          1  Adm-0 scale ranks          1       RUS        RUS      RUS
# 290          1  Adm-0 scale ranks          1       CPV        CPV      CVP
# 291          1  Adm-0 scale ranks          1      TIMI       TIMI     TIMI
# 292          1  Adm-0 scale ranks          1      CLUJ       CLUJ     CLUJ
# 293          1  Adm-0 scale ranks          1       FLA        FLA      FLA
#
#                    sr_geounit  \
# 0                        Fiji
# 1                    Tanzania
# 2              Western Sahara
# 3                      Canada
# 4    United States of America
# ..                        ...
# 289                    Russia
# 290                Cape Verde
# 291                 Timisoara
# 292                      Cluj
# 293                  Flanders
#
#                                               geometry  his_rank
# 0    POLYGON ((180.00000 -16.06713, 180.00000 -16.5...       0.0
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...       0.0
# 2    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...       0.0
# 3    POLYGON ((-122.84000 49.00000, -122.97421 49.0...       0.0
# 4    POLYGON ((-122.84000 49.00000, -120.00000 49.0...       0.0
# ..                                                 ...       ...
# 289  POLYGON ((33.43599 45.97192, 33.69946 46.21957...       1.0
# 290  MULTIPOLYGON (((-25.28500 16.66000, -25.44000 ...       1.0
# 291  MULTIPOLYGON (((20.70416 46.16142, 20.70606 46...       0.6
# 292  MULTIPOLYGON (((24.02456 47.36161, 24.02522 47...       1.0
# 293  MULTIPOLYGON (((5.70000 50.78000, 5.73500 50.7...       0.5
#
# [294 rows x 9 columns]

# %%
his_map = folium.Map(location=[40.406, -10.110], tiles="Cartodb Positron", zoom_start=3, width="%100", height="%100")

folium.Choropleth(
    geo_data=extended_df,
    data=extended_df,
    bins=8,
    columns=['sr_geounit', 'his_rank'],   
    legend_name='Interest in moving to country',
    key_on='feature.properties.sr_geounit',
    line_opacity = 0.1,
    ).add_to(his_map);

# %% [markdown]
# ### Map

# %%
his_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34c9aa946c820f119240b20702d83318 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34c9aa946c820f119240b20702d83318&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_34c9aa946c820f119240b20702d83318 = L.map(
#                 &quot;map_34c9aa946c820f119240b20702d83318&quot;,
#                 {
#                     center: [40.406, -10.11],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_faa17e7491ad6e95c6199fe7432add1c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_34c9aa946c820f119240b20702d83318);
#
#
#             var choropleth_434e28960501a073328af8b82d909f77 = L.featureGroup(
#                 {}
#             ).addTo(map_34c9aa946c820f119240b20702d83318);
#
#
#         function geo_json_4c4e9c64bb896dce1b583ad3db5a2980_styler(feature) {
#             switch(feature.id) {
#                 case &quot;9&quot;: case &quot;56&quot;: case &quot;226&quot;: case &quot;291&quot;: case &quot;293&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6baed6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;19&quot;: case &quot;31&quot;: case &quot;35&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;132&quot;: case &quot;200&quot;: case &quot;201&quot;: case &quot;202&quot;: case &quot;203&quot;: case &quot;216&quot;: case &quot;276&quot;: case &quot;277&quot;: case &quot;279&quot;: case &quot;280&quot;: case &quot;289&quot;: case &quot;290&quot;: case &quot;292&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#084594&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;54&quot;: case &quot;135&quot;: case &quot;144&quot;: case &quot;145&quot;: case &quot;154&quot;: case &quot;255&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#4292c6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;136&quot;: case &quot;215&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2171b5&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;286&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ecae1&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f7fbff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_4c4e9c64bb896dce1b583ad3db5a2980_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4c4e9c64bb896dce1b583ad3db5a2980 = L.geoJson(null, {
#                 onEachFeature: geo_json_4c4e9c64bb896dce1b583ad3db5a2980_onEachFeature,
#
#                 style: geo_json_4c4e9c64bb896dce1b583ad3db5a2980_styler,
#         });
#
#         function geo_json_4c4e9c64bb896dce1b583ad3db5a2980_add (data) {
#             geo_json_4c4e9c64bb896dce1b583ad3db5a2980
#                 .addData(data)
#                 .addTo(choropleth_434e28960501a073328af8b82d909f77);
#         }
#             geo_json_4c4e9c64bb896dce1b583ad3db5a2980_add({&quot;bbox&quot;: [-180.0, -90.0, 180.00000000000006, 83.64513000000001], &quot;features&quot;: [{&quot;bbox&quot;: [178.59683859511713, -17.01204167436804, 180.0, -16.067132663642447], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[180.0, -16.067132663642447], [180.0, -16.555216566639196], [179.36414266196414, -16.801354076946883], [178.72505936299711, -17.01204167436804], [178.59683859511713, -16.639150000000004], [179.0966093629971, -16.433984277547403], [179.4135093629971, -16.379054277547404], [180.0, -16.067132663642447]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;featurecla&quot;: &quot;Adm-0 scale ranks&quot;, &quot;her_rank&quot;: 0.0, &quot;his_rank&quot;: 0.0, &quot;labelrank&quot;: 1, &quot;scalerank&quot;: 1, &quot;sr_adm0_a3&quot;: &quot;FJI&quot;, &quot;sr_geounit&quot;: &quot;Fiji&quot;, &quot;sr_gu_a3&quot;: &quot;FJI&quot;, &quot;sr_sov_a3&quot;: &quot;FJI&quot;}, &quot;type&quot;: &quot;Fe

# %% [markdown]
# ## Where she wants to live

# %% [markdown]
# ### Code and charts

# %%
her_countries = ["Luxemburg", "Portugal", "Finland", "Sweden", "Denmark", "Cluj", "Montenegro", "Serbia", "Croatia", "Czech Republic", "Cyprus", "Austria"]
her_rating = [0.6, 1, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 1, 0.6]
her_countries_df = pd.DataFrame({'countries': her_countries, 'her_rank': her_rating})
her_countries_df
# Out:
#          countries  her_rank
# 0        Luxemburg       0.6
# 1         Portugal       1.0
# 2          Finland       0.6
# 3           Sweden       0.6
# 4          Denmark       0.6
# 5             Cluj       0.6
# 6       Montenegro       0.6
# 7           Serbia       0.6
# 8          Croatia       0.6
# 9   Czech Republic       0.6
# 10          Cyprus       1.0
# 11         Austria       0.6

# %%
extended_df = extended_df.copy()
extended_df = pd.merge(extended_df, her_countries_df, left_on=["sr_geounit"], right_on=["countries"], how="left")
extended_df = extended_df.drop(['countries'], axis=1)
extended_df['her_rank'] = extended_df['her_rank'].fillna(0)
extended_df = extended_df.set_crs(4326, allow_override=True)
extended_df
# Out:
#      scalerank         featurecla  labelrank sr_sov_a3 sr_adm0_a3 sr_gu_a3  \
# 0            1  Adm-0 scale ranks          1       FJI        FJI      FJI
# 1            1  Adm-0 scale ranks          1       TZA        TZA      TZA
# 2            1  Adm-0 scale ranks          1       SAH        SAH      SAH
# 3            1  Adm-0 scale ranks          1       CAN        CAN      CAN
# 4            1  Adm-0 scale ranks          1       US1        USA      USA
# ..         ...                ...        ...       ...        ...      ...
# 289          1  Adm-0 scale ranks          1       RUS        RUS      RUS
# 290          1  Adm-0 scale ranks          1       CPV        CPV      CVP
# 291          1  Adm-0 scale ranks          1      TIMI       TIMI     TIMI
# 292          1  Adm-0 scale ranks          1      CLUJ       CLUJ     CLUJ
# 293          1  Adm-0 scale ranks          1       FLA        FLA      FLA
#
#                    sr_geounit  \
# 0                        Fiji
# 1                    Tanzania
# 2              Western Sahara
# 3                      Canada
# 4    United States of America
# ..                        ...
# 289                    Russia
# 290                Cape Verde
# 291                 Timisoara
# 292                      Cluj
# 293                  Flanders
#
#                                               geometry  his_rank  her_rank
# 0    POLYGON ((180.00000 -16.06713, 180.00000 -16.5...       0.0       0.0
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...       0.0       0.0
# 2    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...       0.0       0.0
# 3    POLYGON ((-122.84000 49.00000, -122.97421 49.0...       0.0       0.0
# 4    POLYGON ((-122.84000 49.00000, -120.00000 49.0...       0.0       0.0
# ..                                                 ...       ...       ...
# 289  POLYGON ((33.43599 45.97192, 33.69946 46.21957...       1.0       0.0
# 290  MULTIPOLYGON (((-25.28500 16.66000, -25.44000 ...       1.0       0.0
# 291  MULTIPOLYGON (((20.70416 46.16142, 20.70606 46...       0.6       0.0
# 292  MULTIPOLYGON (((24.02456 47.36161, 24.02522 47...       1.0       0.6
# 293  MULTIPOLYGON (((5.70000 50.78000, 5.73500 50.7...       0.5       0.0
#
# [294 rows x 10 columns]

# %%
her_map = folium.Map(location=[40.406, -10.110], tiles="Cartodb Positron", zoom_start=3, width="%100", height="%100")

folium.Choropleth(
    geo_data=extended_df,
    data=extended_df,
    fill_color="BuGn",
    bins=8,
    columns=['sr_geounit', 'her_rank'],   
    legend_name='Her interest in moving to country',
    key_on='feature.properties.sr_geounit',
    line_opacity = 0.1,
    ).add_to(her_map);

# %% [markdown]
# ### Map

# %%
her_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74048d3285f86c0b08a25aadb64c5330 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74048d3285f86c0b08a25aadb64c5330&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_74048d3285f86c0b08a25aadb64c5330 = L.map(
#                 &quot;map_74048d3285f86c0b08a25aadb64c5330&quot;,
#                 {
#                     center: [40.406, -10.11],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43f4228ead17f029d27901e6facb1f0b = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74048d3285f86c0b08a25aadb64c5330);
#
#
#             var choropleth_2811a2f36a18e5596a0837f932e1027f = L.featureGroup(
#                 {}
#             ).addTo(map_74048d3285f86c0b08a25aadb64c5330);
#
#
#         function geo_json_651c88f595a7854092e3ba694ebe9c04_styler(feature) {
#             switch(feature.id) {
#                 case &quot;131&quot;: case &quot;135&quot;: case &quot;149&quot;: case &quot;192&quot;: case &quot;193&quot;: case &quot;215&quot;: case &quot;217&quot;: case &quot;276&quot;: case &quot;277&quot;: case &quot;292&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#66c2a4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 case &quot;154&quot;: case &quot;255&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#005824&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f7fcfd&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_651c88f595a7854092e3ba694ebe9c04_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_651c88f595a7854092e3ba694ebe9c04 = L.geoJson(null, {
#                 onEachFeature: geo_json_651c88f595a7854092e3ba694ebe9c04_onEachFeature,
#
#                 style: geo_json_651c88f595a7854092e3ba694ebe9c04_styler,
#         });
#
#         function geo_json_651c88f595a7854092e3ba694ebe9c04_add (data) {
#             geo_json_651c88f595a7854092e3ba694ebe9c04
#                 .addData(data)
#                 .addTo(choropleth_2811a2f36a18e5596a0837f932e1027f);
#         }
#             geo_json_651c88f595a7854092e3ba694ebe9c04_add({&quot;bbox&quot;: [-180.0, -90.0, 180.00000000000006, 83.64513000000001], &quot;features&quot;: [{&quot;bbox&quot;: [178.59683859511713, -17.01204167436804, 180.0, -16.067132663642447], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[180.0, -16.067132663642447], [180.0, -16.555216566639196], [179.36414266196414, -16.801354076946883], [178.72505936299711, -17.01204167436804], [178.59683859511713, -16.639150000000004], [179.0966093629971, -16.433984277547403], [179.4135093629971, -16.379054277547404], [180.0, -16.067132663642447]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;featurecla&quot;: &quot;Adm-0 scale ranks&quot;, &quot;her_rank&quot;: 0.0, &quot;his_rank&quot;: 0.0, &quot;labelrank&quot;: 1, &quot;scalerank&quot;: 1, &quot;sr_adm0_a3&quot;: &quot;FJI&quot;, &quot;sr_geounit&quot;: &quot;Fiji&quot;, &quot;sr_gu_a3&quot;: &quot;FJI&quot;, &quot;sr_sov_a3&quot;: &quot;FJI&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [29.339997592900346, -11.720938002166735, 40.31659000000002, -0.9500000000000001], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[33.90371119710453, -0.9500000000000001], [34.07261999999997, -1.0598199999999451], [37.69868999999994, -3.0969899999999484], [37.7669, -3.6771200000000004], [39.20222, -4.67677], [38.74053999999995, -5.9089499999999475], [38.79977000000008, -6.475660000000005], [39.44, -6.839999999999861], [39.47000000000014, -7.099999999999966], [39.19468999999998, -7.703899999999976], [39.25203000000005, -8.00780999999995], [39.18652000000009, -8.48550999999992], [39.53574000000009, -9.112369999999885], [39.94960000000003, -10.098400000000026], [40.316586229110854, -10.317097752817492], [40.31659000000002, -10.317099999999868], [39.52099999999996, -10.89688000000001], [38.42755659358775, -11.285202325081656], [37.827639999999974, -11.26878999999991], [37.471289999999954, -11.568759999999997], [36.775150994622805, -11.594537448780805], [36.51408165868426, -11.720938002166735], [35.31239790216904, -11.439146416879147], [34.5599890
